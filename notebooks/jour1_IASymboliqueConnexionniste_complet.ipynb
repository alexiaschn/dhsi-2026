# %% [markdown]
# # Jour 1 : Système déductif vs. système inductif
#
# Nous allons essayer de définir un algorithme permettant de classer un épigramme en "parle d'animal" ou non avec les deux approches.

# %%
# !pip install wget pandas

# %%
import pandas as pd
import os

try:
    data = pd.read_csv(f"{os.getcwd()}/corpus/epigrammes_anthologia_graeca_fr.csv")
except FileNotFoundError:
    # !wget -P corpus https://raw.githubusercontent.com/alexiaschn/dhsi-2026/main/notebooks/corpus/epigrammes_anthologia_graeca_fr.csv
    data = pd.read_csv(f"{os.getcwd()}/corpus/epigrammes_anthologia_graeca_fr.csv")


data.head()
# Out:
#    epigramme_id  book  fragment                                       urn  \
# 0         7.114     7       114  urn:cts:greekLit:tlg7000.tlg001.ag:7.114
# 1         7.115     7       115  urn:cts:greekLit:tlg7000.tlg001.ag:7.115
# 2         7.116     7       116  urn:cts:greekLit:tlg7000.tlg001.ag:7.116
# 3         7.120     7       120  urn:cts:greekLit:tlg7000.tlg001.ag:7.120
# 4         7.171     7       171  urn:cts:greekLit:tlg7000.tlg001.ag:7.171
#
#         author_fr                                            text_fr
# 0  Diogène Laërce  Tu voulais, Héraclide, laisser aux hommes le b...
# 1  Diogène Laërce  « Tu as vécu en chien, Antisthène. - C'est que...
# 2  Diogène Laërce  « Diogène, allons, dis-moi quel destin t'a rav...
# 3       Xénophane  On dit qu'un jour il passait devant un jeune c...
# 4       Mnasalcès  Ici aussi l'oiseau sacré reposera son aile rap...

# %% [markdown]
# ## Système expert
#
# Système à base de règle.

# %%
import re

# définition de règle : motif textuel de base

motif_animal = re.compile(r"(chien|chat|souris|rat|pieuvre|marmotte)", flags=re.IGNORECASE)

def contient_animal(texte):
    if re.search(motif_animal, texte):
        print(texte)
        return True
    else:
        return False

for texte in data['text_fr']:
    print(contient_animal(texte))
# Out:
# False
# « Tu as vécu en chien, Antisthène. - C'est que j'étais né pour déchirer le cœur avec des mots et non avec des crocs. - Mais tu es mort en chien que tu étais né, dira sans doute quelqu'un. - Eh quoi ! il fait bien qu'il y en ait pour servir de guide chez Hadès. »
# True
# « Diogène, allons, dis-moi quel destin t'a ravi? - C'est la morsure féroce du Chien, qui m'a ravi chez Hadès. »
# True
# On dit qu'un jour il passait devant un jeune chien qu'on frappait, il en eut compassion et prononça ces paroles : « Arrête et ne frappe plus, car sûrement c'est l'âme d'un ami, que j'ai reconnue en l'entendant crier. »
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %% [markdown]
# Comment pourrions-nous améliorer ce programme ?

# %%
# possible version améliorée du système expert

# récupération d'une liste plus complète de https://liste-animaux.fr/
import wget

# on télécharge la page web, elle s'enregistre automatiquement dans le dossier où se trouve le notebook
page_html = wget.download("https://liste-animaux.fr/")

# import du module BeautifulSoup pour lire les pages HTML
from bs4 import BeautifulSoup

# ouverture de la page HTML
with open(page_html, "r", encoding="utf-8") as f:
    soup = BeautifulSoup(f)
    # extraction de la légende 'alt' de toutes les balises <img> de la page web où se trouve les noms des animaux
    animaux = [animal['alt'] for animal in soup.find_all('img', alt=True)]

print(f"Nombre d'animaux: {len(animaux)}")

print(f"Nom des 5 premiers 'animaux' listés : {animaux[:5]}")
print(f"Nom des 5 derniers 'animaux' listés : {animaux[-5:]}")
# Out:
# Nombre d'animaux: 869
# Nom des 5 premiers 'animaux' listés : ['logo liste animaux', 'Abeille', 'Accenteur mouchet', 'Addax', 'Agneau']
# Nom des 5 derniers 'animaux' listés : ['Zèbre', 'Zébu', 'Zibeline', 'Zorille', 'Zygaène']

# %%
# reformulation du motif, on ignore le premier item de la liste qui est "logo liste animaux" et non un animal
motif_animal_complet = re.compile(rf"({'|'.join(animaux[1:])})", flags=re.IGNORECASE)
print(motif_animal_complet)


def contient_animal_complet(texte):
    return True if re.search(motif_animal_complet, texte) else False

# tous les épigrammes devraient renvoyer True
for texte in data['text_fr']:
    pred = contient_animal_complet(texte)
    print(pred)
    if pred == False:
        print(f"L'épigramme suivant ne mentionne pas d'animal : {texte}")
# Out:
# re.compile('(Abeille|Accenteur mouchet|Addax|Agneau|Agouti|Aigle|Aigrette|Albatros|Alligator|Alouate|Alouette|Alpaga|Amazone|Amblypyge|Anaconda|Anchois|Âne|Anémone de mer|Anguille|Anoa des plaines|Anolis|Antiloc, re.IGNORECASE)
# True
# True
# True
# True
# False
# L'épigramme suivant ne mentionne pas d'animal : Ici aussi l'oiseau sacré reposera son aile rapide, en s' arrêtant sur ce platane plein d'attrait. Il est mort en effet, Poimandros de Mélien, et il ne viendra plus verser sa glu sur ses pipeaux de chasse.
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %% [markdown]
# Avez-vous des idées pour rendre encore plus robuste (c'est à dire capable de couvrir tous les scénarios possibles) ce programme ?
#
# Quelles sont les limites de la logique déductives ?

# %% [markdown]
# ## Système inductif
#
# Nous allons modéliser très rapidement une logique inductive pour réaliser cette classification basique.
#
# Pour cela il nous faut des exemples d'épigrammes qui ne mentionnent **pas** d'animal. Le repo contient le document `epigrammes_no_animal.csv` qu'il faut ajouter manuellement sur l'environnement virtuel Colab.

# %%
# ajout du corpus d'épigrammes ne mentionnant pas d'animal

try:
    data_no_animal = pd.read_csv(f"{os.getcwd()}/corpus/epigrammes_no_animal.csv")
except FileNotFoundError:
    # !wget -P corpus https://raw.githubusercontent.com/alexiaschn/dhsi-2026/main/notebooks/corpus/epigrammes_anthologia_graeca_fr.csv
    data_no_animal = pd.read_csv(f"{os.getcwd()}/corpus/epigrammes_no_animal.csv")


# ajout d'une colonne d'annotation pour chacun des corpus 
# le corpus data_no_animal contient une colonne composée uniquement de la valeur "False"
data_no_animal['animal'] = [False] * len(data_no_animal)
# le corpus data est toujours True
data['animal'] = [True] * len(data)

# concaténation des deux jeux de données
data = pd.concat([data, data_no_animal])
# à droite : nouvelle colonne 'animal' contenant une valeur booléenne (True/False)
data
# Out:
#     epigramme_id  book  fragment                                       urn  \
# 0          7.114     7       114  urn:cts:greekLit:tlg7000.tlg001.ag:7.114
# 1          7.115     7       115  urn:cts:greekLit:tlg7000.tlg001.ag:7.115
# 2          7.116     7       116  urn:cts:greekLit:tlg7000.tlg001.ag:7.116
# 3          7.120     7       120  urn:cts:greekLit:tlg7000.tlg001.ag:7.120
# 4          7.171     7       171  urn:cts:greekLit:tlg7000.tlg001.ag:7.171
# 5          7.172     7       172  urn:cts:greekLit:tlg7000.tlg001.ag:7.172
# 6          7.173     7       173  urn:cts:greekLit:tlg7000.tlg001.ag:7.173
# 7          7.189     7       189  urn:cts:greekLit:tlg7000.tlg001.ag:7.189
# 8          7.190     7       190  urn:cts:greekLit:tlg7000.tlg001.ag:7.190
# 9          7.191     7       191  urn:cts:greekLit:tlg7000.tlg001.ag:7.191
# 10         7.192     7       192  urn:cts:greekLit:tlg7000.tlg001.ag:7.192
# 11         7.195     7       195  urn:cts:greekLit:tlg7000.tlg001.ag:7.195
# 12         7.201     7       201  urn:cts:greekLit:tlg7000.tlg001.ag:7.201
# 13         7.214     7       214  urn:cts:greekLit:tlg7000.tlg001.ag:7.214
# 14         7.216     7       216  urn:cts:greekLit:tlg7000.tlg001.ag:7.216
# 0          5.100     5         1    urn:cts:greekLit:tlg7000.tlg001.ag:5.1
# 1          5.200     5         2    urn:cts:greekLit:tlg7000.tlg001.ag:5.2
# 2          5.300     5         3    urn:cts:greekLit:tlg7000.tlg001.ag:5.3
# 3          5.400     5         4    urn:cts:greekLit:tlg7000.tlg001.ag:5.4
# 4          5.500     5         5    urn:cts:greekLit:tlg7000.tlg001.ag:5.5
# 5          5.600     5         6    urn:cts:greekLit:tlg7000.tlg001.ag:5.6
# 6          5.700     5         7    urn:cts:greekLit:tlg7000.tlg001.ag:5.7
# 7          5.800     5         8    urn:cts:greekLit:tlg7000.tlg001.ag:5.8
# 8          5.900     5         9    urn:cts:greekLit:tlg7000.tlg001.ag:5.9
# 9          5.100     5        10   urn:cts:greekLit:tlg7000.tlg001.ag:5.10
# 10         5.110     5        11   urn:cts:greekLit:tlg7000.tlg001.ag:5.11
# 11         5.120     5        12   urn:cts:greekLit:tlg7000.tlg001.ag:5.12
# 12         5.130     5        13   urn:cts:greekLit:tlg7000.tlg001.ag:5.13
# 13         5.140     5        14   urn:cts:greekLit:tlg7000.tlg001.ag:5.14
# 14         5.150     5        15   urn:cts:greekLit:tlg7000.tlg001.ag:5.15
#
#                                             author_fr  \
# 0                                      Diogène Laërce
# 1                                      Diogène Laërce
# 2                                      Diogène Laërce
# 3                                           Xénophane
# 4                                           Mnasalcès
# 5                                 Antipatros de Sidon
# 6   Diotimos d'Adramytte; Diotime d'Athènes; Léoni...
# 7                               Aristodicos de Rhodes
# 8                          Anytè; Léonidas de Tarente
# 9                        Archias; Archias de Mytilène
# 10                                          Mnasalcès
# 11                                 Méléagre de Gadara
# 12                              Pamphile d'Alexandrie
# 13                       Archias; Archias de Mytilène
# 14                         Antipater de Thessalonique
# 0                                 Constantin Céphalas
# 1                                             anonyme
# 2                          Antipater de Thessalonique
# 3                                 Philodème de Gadara
# 4                                   Statilius Flaccus
# 5                                Callimaque de Cyrène
# 6                                 Asclépiade de Samos
# 7                                  Méléagre de Gadara
# 8                                               Rufin
# 9                                    Alcée de Messène
# 10                                            anonyme
# 11                                              Rufin
# 12                                Philodème de Gadara
# 13                                              Rufin
# 14                                              Rufin
#
#                                               text_fr  animal
# 0   Tu voulais, Héraclide, laisser aux hommes le b...    True
# 1   « Tu as vécu en chien, Antisthène. - C'est que...    True
# 2   « Diogène, allons, dis-moi quel destin t'a rav...    True
# 3   On dit qu'un jour il passait devant un jeune c...    True
# 4   Ici aussi l'oiseau sacré reposera son aile rap...    True
# 5   Moi, Alcimènés, jadis j'écartais l'etourneau e...    True
# 6   D'elles-mêmes, le soir, les vaches sont revenu...    True
# 7   Non, jamais plus, mélodieuse sauterelle, Hélio...    True
# 8   A la sauterelle, rossignol des guérets, à la c...    True
# 9   Moi qui jadis, en renvoyant le sons, répondais...    True
# 10  Jamais plus de tes ailes bruissantes tu ne cha...    True
# 11  Sauterelle, toi qui trompes mes regrets et apa...    True
# 12  Tu ne jettes plus, posée sur les feuilles vert...    True
# 13  Tu ne vas plus t'élancer à travers les profond...    True
# 14  Les flots et les vagues houleuses m'ont jeté s...    True
# 0   Enflammant le cœur des jeunes avec une ferveur...   False
# 1   Sthénélaïde, celle qui fait brûler les villes,...   False
# 2   Le jour se lève, Chrysille, et depuis longtemp...   False
# 3   Philénis, après avoir enivré la lampe qui conn...   False
# 4   Moi, lampe en argent, fidèle témoin des amours...   False
# 5   Callignote a juré à Ionis que jamais il n’aime...   False
# 6   Lampe, devant toi Héraclée a juré trois fois q...   False
# 7   Ô nuit sacrée, ô lampe, tous deux nous n’avons...   False
# 8   Moi, Rufin, à ma très douce Elpis, je souhaite...   False
# 9   Je hais l’Amour : pourquoi, pesant, sur les bê...   False
# 10  Si tu sauves ceux qui sont en mer, Cypris, moi...   False
# 11  Baignons-nous, Prodikè, puis couronnons-nous d...   False
# 12  Charito achève d'accomplir ses soixante révolu...   False
# 13  Le baiser d’Europe, même s’il ne vient qu’aux ...   False
# 14  Où est donc aujourd’hui Praxitèle? où sont les...   False

# %%
# On va créer un dictionnaire pour stocker les "habitudes" des deux catégories (True or False).
# Structure : { mot : { "True": 2, "False": 4, } }
# chaque mot obtient un compteur d'apparition : si le mot "valise" est présent dans une épigramme classée "True" alors "valise" ajoutera un point à son score "True".

modele_appris = {}

# On parcourt toutes les phrases d'entraînement
for index, epigramme in data.iterrows():
    true_or_false = str(epigramme["animal"])

    # On découpe la phrase en mots (en minuscule pour simplifier)
    mots = epigramme['text_fr'].lower().split()

    for mot in mots:
        # Si le mot n'est pas encore dans le modèle, on l'ajoute
        if mot not in modele_appris:
            modele_appris[mot] = {"True": 0, "False": 0}

        # On "apprend" : on incrémente le compteur de la catégorie du mot
        modele_appris[mot][true_or_false] += 1

# %%
# Affichage de ce que l'algorithme a "appris"
print("--- Modèle appris (Fréquence des mots par catégorie) ---")
for mot, scores in modele_appris.items():
    print(f"Mot '{mot}' : {scores}")
# Out:
# --- Modèle appris (Fréquence des mots par catégorie) ---
# Mot 'tu' : {'True': 13, 'False': 5}
# Mot 'voulais,' : {'True': 1, 'False': 0}
# Mot 'héraclide,' : {'True': 1, 'False': 0}
# Mot 'laisser' : {'True': 1, 'False': 0}
# Mot 'aux' : {'True': 6, 'False': 0}
# Mot 'hommes' : {'True': 1, 'False': 0}
# Mot 'le' : {'True': 11, 'False': 15}
# Mot 'bruit' : {'True': 1, 'False': 0}
# Mot 'que' : {'True': 6, 'False': 9}
# Mot 'avais' : {'True': 1, 'False': 0}
# Mot 'été,' : {'True': 1, 'False': 0}
# Mot 'une' : {'True': 6, 'False': 4}
# Mot 'fois' : {'True': 1, 'False': 1}
# Mot 'mort,' : {'True': 1, 'False': 0}
# Mot 'changé' : {'True': 1, 'False': 0}
# Mot 'yeux' : {'True': 1, 'False': 1}
# Mot 'de' : {'True': 30, 'False': 26}
# Mot 'tous' : {'True': 1, 'False': 2}
# Mot 'en' : {'True': 18, 'False': 8}
# Mot 'serpent.' : {'True': 1, 'False': 0}
# Mot 'mais' : {'True': 6, 'False': 7}
# Mot 'fus' : {'True': 3, 'False': 0}
# Mot 'trompé' : {'True': 1, 'False': 0}
# Mot 'dans' : {'True': 5, 'False': 3}
# Mot 'tes' : {'True': 6, 'False': 2}
# Mot 'calculs' : {'True': 1, 'False': 0}
# Mot 'sophistiques' : {'True': 1, 'False': 0}
# Mot ':' : {'True': 4, 'False': 4}
# Mot 'la' : {'True': 20, 'False': 19}
# Mot 'bête,' : {'True': 2, 'False': 0}
# Mot 'effet,' : {'True': 2, 'False': 1}
# Mot 'appartenait' : {'True': 1, 'False': 0}
# Mot 'bien' : {'True': 2, 'False': 3}
# Mot 'au' : {'True': 8, 'False': 4}
# Mot 'genre' : {'True': 2, 'False': 0}
# Mot 'serpent' : {'True': 1, 'False': 0}
# Mot ';' : {'True': 5, 'False': 3}
# Mot 'toi,' : {'True': 1, 'False': 6}
# Mot 'convaicu' : {'True': 1, 'False': 0}
# Mot 'd'être' : {'True': 1, 'False': 0}
# Mot 'pas' : {'True': 3, 'False': 5}
# Mot 'du' : {'True': 8, 'False': 4}
# Mot 'sage.' : {'True': 1, 'False': 0}
# Mot '«' : {'True': 3, 'False': 0}
# Mot 'as' : {'True': 2, 'False': 0}
# Mot 'vécu' : {'True': 1, 'False': 0}
# Mot 'chien,' : {'True': 2, 'False': 0}
# Mot 'antisthène.' : {'True': 1, 'False': 0}
# Mot '-' : {'True': 4, 'False': 2}
# Mot 'c'est' : {'True': 7, 'False': 0}
# Mot 'j'étais' : {'True': 1, 'False': 0}
# Mot 'né' : {'True': 1, 'False': 0}
# Mot 'pour' : {'True': 5, 'False': 4}
# Mot 'déchirer' : {'True': 1, 'False': 0}
# Mot 'cœur' : {'True': 1, 'False': 1}
# Mot 'avec' : {'True': 2, 'False': 2}
# Mot 'des' : {'True': 9, 'False': 11}
# Mot 'mots' : {'True': 1, 'False': 0}
# Mot 'et' : {'True': 16, 'False': 16}
# Mot 'non' : {'True': 1, 'False': 0}
# Mot 'crocs.' : {'True': 1, 'False': 0}
# Mot 'es' : {'True': 1, 'False': 1}
# Mot 'mort' : {'True': 2, 'False': 0}
# Mot 'chien' : {'True': 2, 'False': 0}
# Mot 'étais' : {'True': 1, 'False': 0}
# Mot 'né,' : {'True': 1, 'False': 0}
# Mot 'dira' : {'True': 1, 'False': 0}
# Mot 'sans' : {'True': 3, 'False': 2}
# Mot 'doute' : {'True': 1, 'False': 0}
# Mot 'quelqu'un.' : {'True': 1, 'False': 0}
# Mot 'eh' : {'True': 1, 'False': 0}
# Mot 'quoi' : {'True': 1, 'False': 0}
# Mot '!' : {'True': 1, 'False': 0}
# Mot 'il' : {'True': 6, 'False': 4}
# Mot 'fait' : {'True': 2, 'False': 3}
# Mot 'qu'il' : {'True': 1, 'False': 0}
# Mot 'y' : {'True': 2, 'False': 0}
# Mot 'ait' : {'True': 1, 'False': 0}
# Mot 'servir' : {'True': 1, 'False': 0}
# Mot 'guide' : {'True': 1, 'False': 0}
# Mot 'chez' : {'True': 2, 'False': 0}
# Mot 'hadès.' : {'True': 2, 'False': 0}
# Mot '»' : {'True': 3, 'False': 0}
# Mot 'diogène,' : {'True': 1, 'False': 0}
# Mot 'allons,' : {'True': 1, 'False': 1}
# Mot 'dis-moi' : {'True': 2, 'False': 0}
# Mot 'quel' : {'True': 1, 'False': 1}
# Mot 'destin' : {'True': 1, 'False': 0}
# Mot 't'a' : {'True': 2, 'False': 0}
# Mot 'ravi?' : {'True': 1, 'False': 0}
# Mot 'morsure' : {'True': 1, 'False': 0}
# Mot 'féroce' : {'True': 1, 'False': 0}
# Mot 'qui' : {'True': 14, 'False': 14}
# Mot 'm'a' : {'True': 3, 'False': 0}
# Mot 'ravi' : {'True': 1, 'False': 0}
# Mot 'on' : {'True': 1, 'False': 0}
# Mot 'dit' : {'True': 1, 'False': 1}
# Mot 'qu'un' : {'True': 2, 'False': 0}
# Mot 'jour' : {'True': 1, 'False': 1}
# Mot 'passait' : {'True': 2, 'False': 0}
# Mot 'devant' : {'True': 1, 'False': 1}
# Mot 'un' : {'True': 2, 'False': 6}
# Mot 'jeune' : {'True': 3, 'False': 2}
# Mot 'qu'on' : {'True': 1, 'False': 0}
# Mot 'frappait,' : {'True': 1, 'False': 0}
# Mot 'eut' : {'True': 1, 'False': 0}
# Mot 'compassion' : {'True': 1, 'False': 0}
# Mot 'prononça' : {'True': 1, 'False': 0}
# Mot 'ces' : {'True': 1, 'False': 3}
# Mot 'paroles' : {'True': 1, 'False': 0}
# Mot 'arrête' : {'True': 1, 'False': 0}
# Mot 'ne' : {'True': 7, 'False': 11}
# Mot 'frappe' : {'True': 1, 'False': 0}
# Mot 'plus,' : {'True': 4, 'False': 1}
# Mot 'car' : {'True': 3, 'False': 1}
# Mot 'sûrement' : {'True': 1, 'False': 0}
# Mot 'l'âme' : {'True': 1, 'False': 0}
# Mot 'd'un' : {'True': 2, 'False': 0}
# Mot 'ami,' : {'True': 1, 'False': 0}
# Mot 'j'ai' : {'True': 1, 'False': 0}
# Mot 'reconnue' : {'True': 1, 'False': 0}
# Mot 'l'entendant' : {'True': 1, 'False': 0}
# Mot 'crier.' : {'True': 1, 'False': 0}
# Mot 'ici' : {'True': 1, 'False': 0}
# Mot 'aussi' : {'True': 1, 'False': 1}
# Mot 'l'oiseau' : {'True': 1, 'False': 0}
# Mot 'sacré' : {'True': 1, 'False': 0}
# Mot 'reposera' : {'True': 1, 'False': 0}
# Mot 'son' : {'True': 2, 'False': 2}
# Mot 'aile' : {'True': 1, 'False': 0}
# Mot 'rapide,' : {'True': 1, 'False': 0}
# Mot 's'' : {'True': 1, 'False': 0}
# Mot 'arrêtant' : {'True': 1, 'False': 0}
# Mot 'sur' : {'True': 7, 'False': 4}
# Mot 'ce' : {'True': 3, 'False': 4}
# Mot 'platane' : {'True': 1, 'False': 0}
# Mot 'plein' : {'True': 1, 'False': 0}
# Mot 'd'attrait.' : {'True': 1, 'False': 0}
# Mot 'est' : {'True': 1, 'False': 4}
# Mot 'poimandros' : {'True': 1, 'False': 0}
# Mot 'mélien,' : {'True': 1, 'False': 0}
# Mot 'viendra' : {'True': 1, 'False': 0}
# Mot 'plus' : {'True': 3, 'False': 5}
# Mot 'verser' : {'True': 1, 'False': 0}
# Mot 'sa' : {'True': 2, 'False': 3}
# Mot 'glu' : {'True': 1, 'False': 0}
# Mot 'ses' : {'True': 3, 'False': 6}
# Mot 'pipeaux' : {'True': 1, 'False': 0}
# Mot 'chasse.' : {'True': 1, 'False': 0}
# Mot 'moi,' : {'True': 2, 'False': 2}
# Mot 'alcimènés,' : {'True': 1, 'False': 0}
# Mot 'jadis' : {'True': 1, 'False': 1}
# Mot 'j'écartais' : {'True': 1, 'False': 0}
# Mot 'l'etourneau' : {'True': 1, 'False': 0}
# Mot 'voleuse' : {'True': 1, 'False': 0}
# Mot 'semences,' : {'True': 1, 'False': 0}
# Mot 'grue' : {'True': 1, 'False': 0}
# Mot 'bistonie' : {'True': 1, 'False': 0}
# Mot 'vol' : {'True': 3, 'False': 0}
# Mot 'élevé,' : {'True': 1, 'False': 0}
# Mot 'tendant' : {'True': 1, 'False': 0}
# Mot 'les' : {'True': 15, 'False': 21}
# Mot 'bras' : {'True': 1, 'False': 1}
# Mot 'agiles' : {'True': 1, 'False': 0}
# Mot 'ma' : {'True': 2, 'False': 3}
# Mot 'fronde,' : {'True': 1, 'False': 0}
# Mot 'je' : {'True': 6, 'False': 12}
# Mot 'repoussais' : {'True': 1, 'False': 0}
# Mot 'loin' : {'True': 1, 'False': 0}
# Mot 'nuée' : {'True': 1, 'False': 0}
# Mot 'oiseaux.' : {'True': 1, 'False': 0}
# Mot 'me' : {'True': 2, 'False': 7}
# Mot 'piquant' : {'True': 1, 'False': 0}
# Mot 'près' : {'True': 1, 'False': 0}
# Mot 'cheville,' : {'True': 1, 'False': 0}
# Mot 'vipère' : {'True': 1, 'False': 0}
# Mot 'dipsas' : {'True': 1, 'False': 0}
# Mot 'a' : {'True': 5, 'False': 4}
# Mot 'versé' : {'True': 1, 'False': 0}
# Mot 'chair' : {'True': 1, 'False': 0}
# Mot 'venin' : {'True': 1, 'False': 0}
# Mot 'amer' : {'True': 1, 'False': 0}
# Mot 'mâchoires,' : {'True': 1, 'False': 0}
# Mot 'privant' : {'True': 1, 'False': 0}
# Mot 'vue' : {'True': 1, 'False': 0}
# Mot 'soleil.' : {'True': 1, 'False': 0}
# Mot 'voilà' : {'True': 1, 'False': 0}
# Mot 'comment' : {'True': 1, 'False': 0}
# Mot 'regardant' : {'True': 1, 'False': 0}
# Mot 'l'air,' : {'True': 1, 'False': 0}
# Mot 'n'ai' : {'True': 1, 'False': 0}
# Mot 'vu' : {'True': 2, 'False': 0}
# Mot 'mal' : {'True': 1, 'False': 0}
# Mot 'rampait' : {'True': 1, 'False': 0}
# Mot 'à' : {'True': 7, 'False': 13}
# Mot 'mes' : {'True': 4, 'False': 1}
# Mot 'pieds.' : {'True': 1, 'False': 0}
# Mot 'd'elles-mêmes,' : {'True': 1, 'False': 0}
# Mot 'soir,' : {'True': 1, 'False': 0}
# Mot 'vaches' : {'True': 1, 'False': 0}
# Mot 'sont' : {'True': 1, 'False': 4}
# Mot 'revenues' : {'True': 1, 'False': 0}
# Mot 'montagne' : {'True': 1, 'False': 0}
# Mot 'l'étable,' : {'True': 1, 'False': 0}
# Mot 'couvertes' : {'True': 1, 'False': 0}
# Mot 'd'une' : {'True': 3, 'False': 0}
# Mot 'neige' : {'True': 1, 'False': 0}
# Mot 'abondante' : {'True': 1, 'False': 0}
# Mot 'et,' : {'True': 1, 'False': 0}
# Mot 'hélas,' : {'True': 1, 'False': 0}
# Mot 'pied' : {'True': 1, 'False': 0}
# Mot 'chêne,' : {'True': 1, 'False': 0}
# Mot 'thérimachos' : {'True': 1, 'False': 0}
# Mot 'dort' : {'True': 1, 'False': 0}
# Mot 'sommeil' : {'True': 1, 'False': 1}
# Mot 'éternel' : {'True': 1, 'False': 0}
# Mot 'feu' : {'True': 1, 'False': 1}
# Mot 'ciel' : {'True': 1, 'False': 0}
# Mot 'l'y' : {'True': 1, 'False': 0}
# Mot 'plongé.' : {'True': 1, 'False': 0}
# Mot 'non,' : {'True': 1, 'False': 1}
# Mot 'jamais' : {'True': 3, 'False': 1}
# Mot 'mélodieuse' : {'True': 1, 'False': 0}
# Mot 'sauterelle,' : {'True': 5, 'False': 0}
# Mot 'hélios' : {'True': 1, 'False': 0}
# Mot 'te' : {'True': 3, 'False': 1}
# Mot 'verra' : {'True': 1, 'False': 0}
# Mot 'chanter' : {'True': 1, 'False': 0}
# Mot 'demeure' : {'True': 1, 'False': 0}
# Mot 'opulente' : {'True': 1, 'False': 0}
# Mot 'd'alkis.' : {'True': 1, 'False': 0}
# Mot 'déjà' : {'True': 1, 'False': 0}
# Mot 'effet' : {'True': 1, 'False': 0}
# Mot 'pris' : {'True': 1, 'False': 0}
# Mot 'ton' : {'True': 4, 'False': 1}
# Mot 'vers' : {'True': 1, 'False': 2}
# Mot 'prairies' : {'True': 1, 'False': 0}
# Mot 'clyménos' : {'True': 1, 'False': 0}
# Mot 'fleurs' : {'True': 1, 'False': 0}
# Mot 'humides' : {'True': 2, 'False': 0}
# Mot 'rosée' : {'True': 1, 'False': 0}
# Mot 'rayonnante' : {'True': 1, 'False': 0}
# Mot 'perséphone.' : {'True': 1, 'False': 0}
# Mot 'rossignol' : {'True': 1, 'False': 0}
# Mot 'guérets,' : {'True': 1, 'False': 0}
# Mot 'cigale,' : {'True': 3, 'False': 0}
# Mot 'hôtesse' : {'True': 1, 'False': 0}
# Mot 'hêtres,' : {'True': 1, 'False': 0}
# Mot 'myro' : {'True': 1, 'False': 0}
# Mot 'fit' : {'True': 1, 'False': 0}
# Mot 'tombe' : {'True': 1, 'False': 0}
# Mot 'commune' : {'True': 1, 'False': 0}
# Mot 'elle' : {'True': 1, 'False': 4}
# Mot 'répandit,' : {'True': 1, 'False': 0}
# Mot 'fille,' : {'True': 1, 'False': 0}
# Mot 'larme' : {'True': 1, 'False': 0}
# Mot 'virginale' : {'True': 1, 'False': 0}
# Mot 'l'impitoyable' : {'True': 1, 'False': 0}
# Mot 'hadès' : {'True': 1, 'False': 0}
# Mot 's'en' : {'True': 1, 'False': 0}
# Mot 'allait' : {'True': 1, 'False': 0}
# Mot 'emportant' : {'True': 1, 'False': 0}
# Mot 'double' : {'True': 1, 'False': 0}
# Mot 'objet' : {'True': 1, 'False': 0}
# Mot 'jeux.' : {'True': 1, 'False': 0}
# Mot 'moi' : {'True': 2, 'False': 2}
# Mot 'jadis,' : {'True': 1, 'False': 0}
# Mot 'renvoyant' : {'True': 1, 'False': 0}
# Mot 'sons,' : {'True': 1, 'False': 0}
# Mot 'répondais' : {'True': 1, 'False': 0}
# Mot 'souvent' : {'True': 2, 'False': 0}
# Mot 'pâtres,' : {'True': 1, 'False': 0}
# Mot 'bûcherons' : {'True': 1, 'False': 0}
# Mot 'pêcheurs,' : {'True': 1, 'False': 0}
# Mot 'pie,' : {'True': 1, 'False': 0}
# Mot 'jetais' : {'True': 1, 'False': 0}
# Mot 'cris' : {'True': 1, 'False': 0}
# Mot 'répétés,' : {'True': 1, 'False': 0}
# Mot 'comme' : {'True': 3, 'False': 2}
# Mot 'écho,' : {'True': 1, 'False': 0}
# Mot 'accents' : {'True': 1, 'False': 0}
# Mot 'trompeurs' : {'True': 1, 'False': 0}
# Mot 'voix' : {'True': 1, 'False': 0}
# Mot 'apte' : {'True': 1, 'False': 0}
# Mot 'répondre' : {'True': 1, 'False': 0}
# Mot 'chants,' : {'True': 1, 'False': 0}
# Mot 'maintenant' : {'True': 1, 'False': 4}
# Mot 'tombée' : {'True': 1, 'False': 0}
# Mot 'terre.' : {'True': 1, 'False': 0}
# Mot 'gis' : {'True': 1, 'False': 0}
# Mot 'langue' : {'True': 1, 'False': 0}
# Mot 'voix,' : {'True': 1, 'False': 0}
# Mot 'déchue' : {'True': 1, 'False': 0}
# Mot 'mon' : {'True': 2, 'False': 4}
# Mot 'besoin' : {'True': 1, 'False': 0}
# Mot 'd'imitation.' : {'True': 1, 'False': 0}
# Mot 'ailes' : {'True': 2, 'False': 0}
# Mot 'bruissantes' : {'True': 1, 'False': 0}
# Mot 'chanteras,' : {'True': 1, 'False': 0}
# Mot 'posée' : {'True': 2, 'False': 0}
# Mot 'long' : {'True': 1, 'False': 0}
# Mot 'sillons' : {'True': 1, 'False': 0}
# Mot 'fertiles' : {'True': 1, 'False': 0}
# Mot 'étendu' : {'True': 1, 'False': 0}
# Mot 'l'ombre' : {'True': 1, 'False': 0}
# Mot 'rameaux,' : {'True': 1, 'False': 0}
# Mot 'serai' : {'True': 1, 'False': 0}
# Mot 'charmé' : {'True': 1, 'False': 0}
# Mot 'chant' : {'True': 3, 'False': 0}
# Mot 'mélodieux' : {'True': 1, 'False': 0}
# Mot 'rythmé' : {'True': 1, 'False': 0}
# Mot 'par' : {'True': 1, 'False': 2}
# Mot 'blondes' : {'True': 1, 'False': 0}
# Mot 'ailes.' : {'True': 1, 'False': 0}
# Mot 'toi' : {'True': 2, 'False': 1}
# Mot 'trompes' : {'True': 1, 'False': 0}
# Mot 'regrets' : {'True': 1, 'False': 0}
# Mot 'apaises' : {'True': 1, 'False': 0}
# Mot 'sommeil,' : {'True': 2, 'False': 0}
# Mot 'muse' : {'True': 1, 'False': 0}
# Mot 'agreste' : {'True': 1, 'False': 0}
# Mot 'mélodieux,' : {'True': 1, 'False': 0}
# Mot 'imitation' : {'True': 1, 'False': 0}
# Mot 'naturelle' : {'True': 1, 'False': 0}
# Mot 'lyre,' : {'True': 1, 'False': 0}
# Mot 'quelque' : {'True': 1, 'False': 0}
# Mot 'aimé' : {'True': 1, 'False': 0}
# Mot 'frappant' : {'True': 1, 'False': 0}
# Mot 'pattes' : {'True': 1, 'False': 0}
# Mot 'sonores,' : {'True': 1, 'False': 0}
# Mot 'afin' : {'True': 1, 'False': 0}
# Mot 'm'arracher' : {'True': 1, 'False': 0}
# Mot 'souci' : {'True': 1, 'False': 0}
# Mot 'peines' : {'True': 1, 'False': 0}
# Mot 'm'enlèvent' : {'True': 1, 'False': 0}
# Mot 'sais' : {'True': 1, 'False': 0}
# Mot 'chants' : {'True': 1, 'False': 1}
# Mot 'trompent' : {'True': 1, 'False': 0}
# Mot 'l'amour.' : {'True': 1, 'False': 0}
# Mot 'réveil' : {'True': 1, 'False': 0}
# Mot 'donnerai' : {'True': 1, 'False': 0}
# Mot 'récompense' : {'True': 1, 'False': 0}
# Mot 'poireau' : {'True': 1, 'False': 0}
# Mot 'toujours' : {'True': 1, 'False': 3}
# Mot 'vert' : {'True': 1, 'False': 0}
# Mot 'plantes' : {'True': 1, 'False': 0}
# Mot 'rosée,' : {'True': 1, 'False': 0}
# Mot 'diviseras' : {'True': 1, 'False': 0}
# Mot 'lèvres.' : {'True': 1, 'False': 0}
# Mot 'jettes' : {'True': 1, 'False': 0}
# Mot 'feuilles' : {'True': 1, 'False': 0}
# Mot 'vertes,' : {'True': 1, 'False': 0}
# Mot 'l'agréable' : {'True': 1, 'False': 0}
# Mot 'chanson' : {'True': 1, 'False': 0}
# Mot 'cri' : {'True': 1, 'False': 0}
# Mot 'perçant' : {'True': 1, 'False': 0}
# Mot 'quand' : {'True': 1, 'False': 0}
# Mot 'chantais,' : {'True': 1, 'False': 0}
# Mot 'stridente' : {'True': 1, 'False': 0}
# Mot 'garçon' : {'True': 1, 'False': 0}
# Mot 'tua' : {'True': 1, 'False': 0}
# Mot 'main' : {'True': 1, 'False': 0}
# Mot 'tendue.' : {'True': 1, 'False': 0}
# Mot 'vas' : {'True': 1, 'False': 0}
# Mot 't'élancer' : {'True': 1, 'False': 0}
# Mot 'travers' : {'True': 1, 'False': 0}
# Mot 'profondeurs' : {'True': 1, 'False': 0}
# Mot 'bouillonnantes' : {'True': 1, 'False': 0}
# Mot 'mer,' : {'True': 2, 'False': 1}
# Mot 'ô' : {'True': 1, 'False': 3}
# Mot 'dauphin,' : {'True': 2, 'False': 0}
# Mot 'effrayer' : {'True': 1, 'False': 0}
# Mot 'troupeaux' : {'True': 1, 'False': 0}
# Mot 'marins' : {'True': 1, 'False': 0}
# Mot 'ni' : {'True': 1, 'False': 1}
# Mot 'danser' : {'True': 1, 'False': 0}
# Mot 'flûte' : {'True': 1, 'False': 0}
# Mot 'percée' : {'True': 1, 'False': 0}
# Mot 'trous,' : {'True': 1, 'False': 0}
# Mot 'faisant' : {'True': 1, 'False': 0}
# Mot 'jaillir' : {'True': 1, 'False': 0}
# Mot 'l'eau' : {'True': 1, 'False': 0}
# Mot 'autour' : {'True': 1, 'False': 0}
# Mot 'barques' : {'True': 1, 'False': 0}
# Mot 'ni,' : {'True': 1, 'False': 0}
# Mot 'tout' : {'True': 1, 'False': 2}
# Mot 'écumant,' : {'True': 1, 'False': 0}
# Mot 'prendre' : {'True': 1, 'False': 0}
# Mot 'dos' : {'True': 1, 'False': 0}
# Mot 'autrefois' : {'True': 1, 'False': 0}
# Mot 'néréides,' : {'True': 1, 'False': 0}
# Mot 'porter' : {'True': 1, 'False': 0}
# Mot 'jusqu'aux' : {'True': 1, 'False': 0}
# Mot 'bornes' : {'True': 1, 'False': 0}
# Mot 'l'empire' : {'True': 1, 'False': 0}
# Mot 'téthys.' : {'True': 1, 'False': 0}
# Mot 'vague,' : {'True': 1, 'False': 0}
# Mot 'pareille' : {'True': 1, 'False': 0}
# Mot 'promontoire' : {'True': 1, 'False': 0}
# Mot 'malée,' : {'True': 1, 'False': 0}
# Mot 's'est' : {'True': 1, 'False': 0}
# Mot 'soulevée' : {'True': 1, 'False': 0}
# Mot 'jeté' : {'True': 2, 'False': 0}
# Mot 'sables' : {'True': 1, 'False': 0}
# Mot 'cailloux' : {'True': 1, 'False': 0}
# Mot 'rivage.' : {'True': 1, 'False': 0}
# Mot 'flots' : {'True': 1, 'False': 1}
# Mot 'vagues' : {'True': 1, 'False': 0}
# Mot 'houleuses' : {'True': 1, 'False': 0}
# Mot 'm'ont' : {'True': 2, 'False': 0}
# Mot 'rivage,' : {'True': 1, 'False': 0}
# Mot 'passants' : {'True': 1, 'False': 0}
# Mot 'étrange' : {'True': 1, 'False': 0}
# Mot 'vision' : {'True': 1, 'False': 0}
# Mot 'd'infortune.' : {'True': 1, 'False': 0}
# Mot 'terre' : {'True': 1, 'False': 1}
# Mot 'place' : {'True': 1, 'False': 0}
# Mot 'pitié' : {'True': 1, 'False': 0}
# Mot 'ceux' : {'True': 1, 'False': 2}
# Mot 'm'avaient' : {'True': 1, 'False': 0}
# Mot 'aussitôt,' : {'True': 1, 'False': 0}
# Mot 'leur' : {'True': 1, 'False': 1}
# Mot 'piété,' : {'True': 1, 'False': 0}
# Mot 'honoré' : {'True': 1, 'False': 0}
# Mot 'tombeau.' : {'True': 1, 'False': 0}
# Mot 'celle' : {'True': 1, 'False': 3}
# Mot 'enfanté,' : {'True': 1, 'False': 0}
# Mot 'périr.' : {'True': 1, 'False': 0}
# Mot 'quelle' : {'True': 1, 'False': 0}
# Mot 'confiance' : {'True': 1, 'False': 0}
# Mot 'avoir' : {'True': 1, 'False': 2}
# Mot 'l'océan,' : {'True': 1, 'False': 0}
# Mot 'n'a' : {'True': 1, 'False': 0}
# Mot 'même' : {'True': 1, 'False': 2}
# Mot 'épargné' : {'True': 1, 'False': 0}
# Mot 'propre' : {'True': 1, 'False': 0}
# Mot 'nourrisson' : {'True': 1, 'False': 0}
# Mot '?' : {'True': 1, 'False': 1}
# Mot 'enflammant' : {'True': 0, 'False': 1}
# Mot 'jeunes' : {'True': 0, 'False': 2}
# Mot 'ferveur' : {'True': 0, 'False': 1}
# Mot 'savante,' : {'True': 0, 'False': 1}
# Mot 'ferai' : {'True': 0, 'False': 1}
# Mot 'l’amour' : {'True': 0, 'False': 3}
# Mot 'soit' : {'True': 0, 'False': 3}
# Mot 'commencement' : {'True': 0, 'False': 1}
# Mot 'discours' : {'True': 0, 'False': 1}
# Mot 'c’est' : {'True': 0, 'False': 2}
# Mot 'lui,' : {'True': 0, 'False': 1}
# Mot 'allume' : {'True': 0, 'False': 1}
# Mot 'flambeau' : {'True': 0, 'False': 1}
# Mot 'sthénélaïde,' : {'True': 0, 'False': 1}
# Mot 'brûler' : {'True': 0, 'False': 1}
# Mot 'villes,' : {'True': 0, 'False': 1}
# Mot 'se' : {'True': 0, 'False': 2}
# Mot 'payer' : {'True': 0, 'False': 1}
# Mot 'cher,' : {'True': 0, 'False': 1}
# Mot 'crache' : {'True': 0, 'False': 1}
# Mot 'l’or' : {'True': 0, 'False': 1}
# Mot 'd’après' : {'True': 0, 'False': 1}
# Mot 'désirent,' : {'True': 0, 'False': 1}
# Mot 'rêve' : {'True': 0, 'False': 1}
# Mot 'l’a' : {'True': 0, 'False': 2}
# Mot 'couchée' : {'True': 0, 'False': 1}
# Mot 'nue' : {'True': 0, 'False': 1}
# Mot 'côtés' : {'True': 0, 'False': 1}
# Mot 'toute' : {'True': 0, 'False': 2}
# Mot 'nuit' : {'True': 0, 'False': 2}
# Mot 'donnant' : {'True': 0, 'False': 1}
# Mot 'plaisir' : {'True': 0, 'False': 1}
# Mot 'gratuitement' : {'True': 0, 'False': 1}
# Mot 'jusqu’à' : {'True': 0, 'False': 1}
# Mot 'l’aurore.' : {'True': 0, 'False': 1}
# Mot 'devrai' : {'True': 0, 'False': 1}
# Mot 'supplier' : {'True': 0, 'False': 1}
# Mot 'genoux,' : {'True': 0, 'False': 1}
# Mot 'cette' : {'True': 0, 'False': 5}
# Mot 'barbare,' : {'True': 0, 'False': 1}
# Mot 'pleurer' : {'True': 0, 'False': 1}
# Mot 'moi-même,' : {'True': 0, 'False': 1}
# Mot 'parce' : {'True': 0, 'False': 1}
# Mot 'j’ai' : {'True': 0, 'False': 1}
# Mot 'm’accorde' : {'True': 0, 'False': 1}
# Mot 'plaisirs.' : {'True': 0, 'False': 1}
# Mot 'lève,' : {'True': 0, 'False': 1}
# Mot 'chrysille,' : {'True': 0, 'False': 1}
# Mot 'depuis' : {'True': 0, 'False': 1}
# Mot 'longtemps,' : {'True': 0, 'False': 1}
# Mot 'coq' : {'True': 0, 'False': 1}
# Mot 'matinier' : {'True': 0, 'False': 1}
# Mot 'chantant' : {'True': 0, 'False': 1}
# Mot 'apparaître' : {'True': 0, 'False': 1}
# Mot 'l’aurore' : {'True': 0, 'False': 1}
# Mot 'envieuse.' : {'True': 0, 'False': 1}
# Mot 'va' : {'True': 0, 'False': 1}
# Mot 'diable' : {'True': 0, 'False': 1}
# Mot 'jaloux' : {'True': 0, 'False': 1}
# Mot 'oiseaux,' : {'True': 0, 'False': 1}
# Mot 'presse' : {'True': 0, 'False': 1}
# Mot 'hors' : {'True': 0, 'False': 1}
# Mot 'maison' : {'True': 0, 'False': 2}
# Mot 'nombreux' : {'True': 0, 'False': 1}
# Mot 'célibataires.' : {'True': 0, 'False': 1}
# Mot 'vieillis,' : {'True': 0, 'False': 1}
# Mot 'tithon' : {'True': 0, 'False': 1}
# Mot 'pourquoi' : {'True': 0, 'False': 1}
# Mot 'sinon' : {'True': 0, 'False': 1}
# Mot 'chasses' : {'True': 0, 'False': 1}
# Mot 'épouse' : {'True': 0, 'False': 1}
# Mot 'aurore' : {'True': 0, 'False': 1}
# Mot 'lit' : {'True': 0, 'False': 2}
# Mot 'si' : {'True': 0, 'False': 5}
# Mot 'tôt' : {'True': 0, 'False': 1}
# Mot 'philénis,' : {'True': 0, 'False': 1}
# Mot 'après' : {'True': 0, 'False': 1}
# Mot 'enivré' : {'True': 0, 'False': 1}
# Mot 'lampe' : {'True': 0, 'False': 2}
# Mot 'connaît' : {'True': 0, 'False': 1}
# Mot 'garde' : {'True': 0, 'False': 1}
# Mot 'secrètes' : {'True': 0, 'False': 1}
# Mot 'choses' : {'True': 0, 'False': 1}
# Mot 'qu’on' : {'True': 0, 'False': 1}
# Mot 'peut' : {'True': 0, 'False': 2}
# Mot 'dire' : {'True': 0, 'False': 2}
# Mot 'd’une' : {'True': 0, 'False': 1}
# Mot 'liqueur' : {'True': 0, 'False': 1}
# Mot 'huileuse,' : {'True': 0, 'False': 1}
# Mot 'va-t-en' : {'True': 0, 'False': 1}
# Mot 'solitaire' : {'True': 0, 'False': 1}
# Mot 'n’apprécie' : {'True': 0, 'False': 1}
# Mot 'témoins' : {'True': 0, 'False': 1}
# Mot 'vivants,' : {'True': 0, 'False': 1}
# Mot 'ferme' : {'True': 0, 'False': 1}
# Mot 'porte,' : {'True': 0, 'False': 1}
# Mot 'philénis.' : {'True': 0, 'False': 1}
# Mot 'embrasse-moi,' : {'True': 0, 'False': 1}
# Mot 'xantho' : {'True': 0, 'False': 1}
# Mot 'quant' : {'True': 0, 'False': 1}
# Mot 'aime' : {'True': 0, 'False': 1}
# Mot 'aimants,' : {'True': 0, 'False': 1}
# Mot 'apprends' : {'True': 0, 'False': 1}
# Mot 'qu’il' : {'True': 0, 'False': 3}
# Mot 'faut' : {'True': 0, 'False': 1}
# Mot 'savoir' : {'True': 0, 'False': 1}
# Mot 'd’aphrodite.' : {'True': 0, 'False': 1}
# Mot 'argent,' : {'True': 0, 'False': 1}
# Mot 'fidèle' : {'True': 0, 'False': 1}
# Mot 'témoin' : {'True': 0, 'False': 2}
# Mot 'amours' : {'True': 0, 'False': 1}
# Mot 'nocturnes,' : {'True': 0, 'False': 1}
# Mot 'flaccus' : {'True': 0, 'False': 1}
# Mot 'm’a' : {'True': 0, 'False': 1}
# Mot 'donnée' : {'True': 0, 'False': 1}
# Mot 'l’infidèle' : {'True': 0, 'False': 1}
# Mot 'nape,' : {'True': 0, 'False': 1}
# Mot 'consomme' : {'True': 0, 'False': 1}
# Mot 'côté' : {'True': 0, 'False': 1}
# Mot 'lit,' : {'True': 0, 'False': 2}
# Mot 'pendant' : {'True': 0, 'False': 2}
# Mot 'regarde' : {'True': 0, 'False': 1}
# Mot 'toutes' : {'True': 0, 'False': 1}
# Mot 'horreurs' : {'True': 0, 'False': 1}
# Mot 'insupportables' : {'True': 0, 'False': 1}
# Mot 'fille' : {'True': 0, 'False': 1}
# Mot 'parjure.' : {'True': 0, 'False': 1}
# Mot 'flaccus,' : {'True': 0, 'False': 1}
# Mot 'réveillé,' : {'True': 0, 'False': 1}
# Mot 'troublantes' : {'True': 0, 'False': 1}
# Mot 'angoisses' : {'True': 0, 'False': 1}
# Mot 't’accablent' : {'True': 0, 'False': 1}
# Mot 'deux,' : {'True': 0, 'False': 1}
# Mot 'nous' : {'True': 0, 'False': 4}
# Mot 'brûlons,' : {'True': 0, 'False': 1}
# Mot 'chacun' : {'True': 0, 'False': 1}
# Mot 'notre' : {'True': 0, 'False': 1}
# Mot 'côté.' : {'True': 0, 'False': 1}
# Mot 'callignote' : {'True': 0, 'False': 1}
# Mot 'juré' : {'True': 0, 'False': 3}
# Mot 'ionis' : {'True': 0, 'False': 1}
# Mot 'n’aimera' : {'True': 0, 'False': 1}
# Mot 'quelqu’un' : {'True': 0, 'False': 1}
# Mot 'homme' : {'True': 0, 'False': 1}
# Mot 'ou' : {'True': 0, 'False': 2}
# Mot 'femme' : {'True': 0, 'False': 1}
# Mot 'qu’elle.' : {'True': 0, 'False': 1}
# Mot 'juré;' : {'True': 0, 'False': 1}
# Mot 'gens' : {'True': 0, 'False': 1}
# Mot 'disent' : {'True': 0, 'False': 1}
# Mot 'vrai:' : {'True': 0, 'False': 1}
# Mot 'serments' : {'True': 0, 'False': 3}
# Mot 'amour' : {'True': 0, 'False': 1}
# Mot 'n’atteignent' : {'True': 0, 'False': 1}
# Mot 'oreilles' : {'True': 0, 'False': 1}
# Mot 'immortels.' : {'True': 0, 'False': 1}
# Mot 'réchauffe,' : {'True': 0, 'False': 1}
# Mot 'homme:' : {'True': 0, 'False': 1}
# Mot 'pauvre' : {'True': 0, 'False': 1}
# Mot 'épouse,' : {'True': 0, 'False': 1}
# Mot 'mégariens,' : {'True': 0, 'False': 1}
# Mot 'n’en' : {'True': 0, 'False': 1}
# Mot 'tient' : {'True': 0, 'False': 1}
# Mot 'compte.' : {'True': 0, 'False': 1}
# Mot 'lampe,' : {'True': 0, 'False': 4}
# Mot 'héraclée' : {'True': 0, 'False': 1}
# Mot 'trois' : {'True': 0, 'False': 1}
# Mot 'qu’elle' : {'True': 0, 'False': 3}
# Mot 'viendrait' : {'True': 0, 'False': 1}
# Mot 'vient' : {'True': 0, 'False': 2}
# Mot 'pas:' : {'True': 0, 'False': 1}
# Mot 'dieu,' : {'True': 0, 'False': 1}
# Mot 'punis' : {'True': 0, 'False': 1}
# Mot 'traitresse,' : {'True': 0, 'False': 1}
# Mot 'batifole' : {'True': 0, 'False': 1}
# Mot 'amant' : {'True': 0, 'False': 1}
# Mot 'éteins-toi' : {'True': 0, 'False': 1}
# Mot 'fais' : {'True': 0, 'False': 2}
# Mot 'lumière.' : {'True': 0, 'False': 1}
# Mot 'sacrée,' : {'True': 0, 'False': 1}
# Mot 'deux' : {'True': 0, 'False': 1}
# Mot 'n’avons' : {'True': 0, 'False': 1}
# Mot 'voulu' : {'True': 0, 'False': 1}
# Mot 'aucun' : {'True': 0, 'False': 1}
# Mot 'autre' : {'True': 0, 'False': 1}
# Mot 'nos' : {'True': 0, 'False': 1}
# Mot 'vous' : {'True': 0, 'False': 3}
# Mot 'avons' : {'True': 0, 'False': 1}
# Mot 'lui' : {'True': 0, 'False': 2}
# Mot 'm’aimerait,' : {'True': 0, 'False': 1}
# Mot 'quitterais' : {'True': 0, 'False': 1}
# Mot 'jamais,' : {'True': 0, 'False': 1}
# Mot 'ensemble' : {'True': 0, 'False': 1}
# Mot 'détenez' : {'True': 0, 'False': 1}
# Mot 'preuve.' : {'True': 0, 'False': 1}
# Mot 'écrits' : {'True': 0, 'False': 1}
# Mot 'l’eau,' : {'True': 0, 'False': 1}
# Mot 'vois' : {'True': 0, 'False': 1}
# Mot 'd’autres' : {'True': 0, 'False': 1}
# Mot 'personnes.' : {'True': 0, 'False': 1}
# Mot 'rufin,' : {'True': 0, 'False': 1}
# Mot 'très' : {'True': 0, 'False': 1}
# Mot 'douce' : {'True': 0, 'False': 1}
# Mot 'elpis,' : {'True': 0, 'False': 1}
# Mot 'souhaite' : {'True': 0, 'False': 1}
# Mot 'joie,' : {'True': 0, 'False': 1}
# Mot 'joie' : {'True': 0, 'False': 1}
# Mot 'absence.' : {'True': 0, 'False': 1}
# Mot 'puis' : {'True': 0, 'False': 2}
# Mot 'j’en' : {'True': 0, 'False': 1}
# Mot 'jure' : {'True': 0, 'False': 1}
# Mot 'yeux,' : {'True': 0, 'False': 2}
# Mot 'supporter' : {'True': 0, 'False': 1}
# Mot 'séparation' : {'True': 0, 'False': 1}
# Mot 'd’avec' : {'True': 0, 'False': 1}
# Mot 'solitude' : {'True': 0, 'False': 1}
# Mot 'cet' : {'True': 0, 'False': 1}
# Mot 'isolement' : {'True': 0, 'False': 1}
# Mot 'auquel' : {'True': 0, 'False': 1}
# Mot 'condamne' : {'True': 0, 'False': 1}
# Mot 'baigné' : {'True': 0, 'False': 1}
# Mot 'larmes,' : {'True': 0, 'False': 1}
# Mot 'm’en' : {'True': 0, 'False': 1}
# Mot 'vais' : {'True': 0, 'False': 1}
# Mot 'coressos' : {'True': 0, 'False': 1}
# Mot 'temple' : {'True': 0, 'False': 1}
# Mot 'grande' : {'True': 0, 'False': 1}
# Mot 'artémis.' : {'True': 0, 'False': 1}
# Mot 'demain' : {'True': 0, 'False': 1}
# Mot 'patrie' : {'True': 0, 'False': 1}
# Mot 'm’aura' : {'True': 0, 'False': 1}
# Mot 'reçu' : {'True': 0, 'False': 1}
# Mot 'volerai' : {'True': 0, 'False': 1}
# Mot 'adieu' : {'True': 0, 'False': 1}
# Mot 'encore' : {'True': 0, 'False': 2}
# Mot 'mille' : {'True': 0, 'False': 1}
# Mot 'fois.' : {'True': 0, 'False': 1}
# Mot 'hais' : {'True': 0, 'False': 1}
# Mot 'pourquoi,' : {'True': 0, 'False': 1}
# Mot 'pesant,' : {'True': 0, 'False': 1}
# Mot 'bêtes' : {'True': 0, 'False': 1}
# Mot 'sauvages' : {'True': 0, 'False': 1}
# Mot 's’élance-t-il' : {'True': 0, 'False': 1}
# Mot 'pas,' : {'True': 0, 'False': 1}
# Mot 'alors' : {'True': 0, 'False': 1}
# Mot 'jette' : {'True': 0, 'False': 1}
# Mot 'traits' : {'True': 0, 'False': 1}
# Mot 'cœur?' : {'True': 0, 'False': 1}
# Mot 'qu’a-t-il' : {'True': 0, 'False': 1}
# Mot 'gagner,' : {'True': 0, 'False': 1}
# Mot 'dieu' : {'True': 0, 'False': 1}
# Mot 'consume' : {'True': 0, 'False': 1}
# Mot 'homme?' : {'True': 0, 'False': 1}
# Mot 'trophée' : {'True': 0, 'False': 1}
# Mot 'tuant,' : {'True': 0, 'False': 1}
# Mot 'tire-t-il' : {'True': 0, 'False': 1}
# Mot 'tête?' : {'True': 0, 'False': 1}
# Mot 'sauves' : {'True': 0, 'False': 1}
# Mot 'cypris,' : {'True': 0, 'False': 1}
# Mot 'naufrage;' : {'True': 0, 'False': 1}
# Mot 'déesse' : {'True': 0, 'False': 1}
# Mot 'bienveillante,' : {'True': 0, 'False': 1}
# Mot 'sauve-moi' : {'True': 0, 'False': 1}
# Mot 'perdition.' : {'True': 0, 'False': 1}
# Mot 'baignons-nous,' : {'True': 0, 'False': 1}
# Mot 'prodikè,' : {'True': 0, 'False': 1}
# Mot 'couronnons-nous' : {'True': 0, 'False': 1}
# Mot 'fleurs,' : {'True': 0, 'False': 1}
# Mot 'humer' : {'True': 0, 'False': 1}
# Mot 'vin' : {'True': 0, 'False': 1}
# Mot 'pur' : {'True': 0, 'False': 1}
# Mot 'prenons' : {'True': 0, 'False': 1}
# Mot 'coupes' : {'True': 0, 'False': 1}
# Mot 'grandes.' : {'True': 0, 'False': 1}
# Mot 'l'âge' : {'True': 0, 'False': 1}
# Mot 'jouissances' : {'True': 0, 'False': 1}
# Mot 'court' : {'True': 0, 'False': 1}
# Mot 'vie;' : {'True': 0, 'False': 1}
# Mot 'ensuite,' : {'True': 0, 'False': 1}
# Mot 'reste' : {'True': 0, 'False': 1}
# Mot 'temps,' : {'True': 0, 'False': 1}
# Mot 'vieillesse' : {'True': 0, 'False': 1}
# Mot 'interdira,' : {'True': 0, 'False': 1}
# Mot 'finir' : {'True': 0, 'False': 1}
# Mot 'sera' : {'True': 0, 'False': 1}
# Mot 'mort.' : {'True': 0, 'False': 1}
# Mot 'charito' : {'True': 0, 'False': 1}
# Mot 'achève' : {'True': 0, 'False': 1}
# Mot 'd'accomplir' : {'True': 0, 'False': 1}
# Mot 'soixante' : {'True': 0, 'False': 1}
# Mot 'révolutions' : {'True': 0, 'False': 1}
# Mot 'annuelles,' : {'True': 0, 'False': 1}
# Mot 'longs' : {'True': 0, 'False': 1}
# Mot 'cheveux' : {'True': 0, 'False': 1}
# Mot 'noirs' : {'True': 0, 'False': 1}
# Mot 'poitrine' : {'True': 0, 'False': 1}
# Mot 'seins' : {'True': 0, 'False': 1}
# Mot 'marbre' : {'True': 0, 'False': 1}
# Mot 'dressent' : {'True': 0, 'False': 1}
# Mot 'pointe,' : {'True': 0, 'False': 1}
# Mot 'qu'aucune' : {'True': 0, 'False': 1}
# Mot 'ceinture' : {'True': 0, 'False': 1}
# Mot 'emprisonne;' : {'True': 0, 'False': 1}
# Mot 'peau,' : {'True': 0, 'False': 1}
# Mot 'flétrit' : {'True': 0, 'False': 1}
# Mot 'aucune' : {'True': 0, 'False': 1}
# Mot 'ride,' : {'True': 0, 'False': 1}
# Mot 'distille' : {'True': 0, 'False': 1}
# Mot 'l'ambroisie,' : {'True': 0, 'False': 1}
# Mot 'séductions' : {'True': 0, 'False': 1}
# Mot 'sorte' : {'True': 0, 'False': 1}
# Mot 'grâces' : {'True': 0, 'False': 1}
# Mot 'innombrables.' : {'True': 0, 'False': 1}
# Mot 'fuyez' : {'True': 0, 'False': 1}
# Mot 'désirs' : {'True': 0, 'False': 1}
# Mot 'bouillonnants,' : {'True': 0, 'False': 1}
# Mot 'vrais' : {'True': 0, 'False': 1}
# Mot 'amants,' : {'True': 0, 'False': 1}
# Mot 'venez' : {'True': 0, 'False': 1}
# Mot 'ici,' : {'True': 0, 'False': 1}
# Mot 'regarder' : {'True': 0, 'False': 1}
# Mot 'nombre' : {'True': 0, 'False': 1}
# Mot 'décades.' : {'True': 0, 'False': 1}
# Mot 'baiser' : {'True': 0, 'False': 1}
# Mot 'd’europe,' : {'True': 0, 'False': 1}
# Mot 's’il' : {'True': 0, 'False': 2}
# Mot 'qu’aux' : {'True': 0, 'False': 1}
# Mot 'lèvres' : {'True': 0, 'False': 2}
# Mot 'doux,' : {'True': 0, 'False': 1}
# Mot 'touche' : {'True': 0, 'False': 1}
# Mot 'qu’à' : {'True': 0, 'False': 1}
# Mot 'surface' : {'True': 0, 'False': 1}
# Mot 'bouche.' : {'True': 0, 'False': 1}
# Mot 'n’est' : {'True': 0, 'False': 1}
# Mot 'bout' : {'True': 0, 'False': 1}
# Mot 'touche,' : {'True': 0, 'False': 1}
# Mot 'luttant' : {'True': 0, 'False': 1}
# Mot 'bouche,' : {'True': 0, 'False': 1}
# Mot 'vide' : {'True': 0, 'False': 1}
# Mot 'complètement' : {'True': 0, 'False': 1}
# Mot 'âme.' : {'True': 0, 'False': 1}
# Mot 'où' : {'True': 0, 'False': 4}
# Mot 'donc' : {'True': 0, 'False': 1}
# Mot 'aujourd’hui' : {'True': 0, 'False': 1}
# Mot 'praxitèle?' : {'True': 0, 'False': 1}
# Mot 'mains' : {'True': 0, 'False': 1}
# Mot 'polyclète' : {'True': 0, 'False': 1}
# Mot 'conféraient' : {'True': 0, 'False': 1}
# Mot 'âme' : {'True': 0, 'False': 1}
# Mot 'œuvres?' : {'True': 0, 'False': 1}
# Mot 'façonnera' : {'True': 0, 'False': 1}
# Mot 'tresses' : {'True': 0, 'False': 1}
# Mot 'parfumées' : {'True': 0, 'False': 1}
# Mot 'mélite,' : {'True': 0, 'False': 1}
# Mot 'brûlants,' : {'True': 0, 'False': 1}
# Mot 'splendeur' : {'True': 0, 'False': 1}
# Mot 'cou?' : {'True': 0, 'False': 1}
# Mot 'mouleurs?' : {'True': 0, 'False': 1}
# Mot 'maçons?' : {'True': 0, 'False': 1}
# Mot 'convient' : {'True': 0, 'False': 1}
# Mot 'telle' : {'True': 0, 'False': 1}
# Mot 'beauté,' : {'True': 0, 'False': 1}
# Mot 'd’avoir' : {'True': 0, 'False': 1}
# Mot 'temple,' : {'True': 0, 'False': 1}
# Mot 'effigie' : {'True': 0, 'False': 1}
# Mot 'bienheureux.' : {'True': 0, 'False': 1}

# %%
# 3. LA PHASE DE PRÉDICTION (Classification d'une nouvelle phrase)
def classifier_nouvelle_phrase(texte_nouveau):
    mots = texte_nouveau.lower().split()
    scores_prediction = {"True": 0, "False": 0}

    for mot in mots:
        # Si le mot a été vu pendant l'apprentissage
        if mot in modele_appris:
            # On ajoute les scores appris pour ce mot
            for categorie in scores_prediction:
                scores_prediction[categorie] += modele_appris[mot][categorie]
        else:
            # Si le mot est inconnu, on le traite comme neutre (ou on ignore)
            # Pour simplifier, on ignore ici.
            pass

    # On retourne la catégorie avec le score le plus élevé
    categorie_gagnante = max(scores_prediction, key=scores_prediction.get)
    return categorie_gagnante, scores_prediction

# 4. TESTS
print("\n--- Tests de classification ---")
phrases_tests = [
    "Tu es un beau chat.",
    "Les plumes de cet animal chatoient.",
    "La facture a été payée"
]

for phrase in phrases_tests:
    categorie, scores = classifier_nouvelle_phrase(phrase)
    print(f"Phrase : '{phrase}'")
    print(f"-> Prédiction : {categorie} (Scores : {scores})")
# Out:
# --- Tests de classification ---
# Phrase : 'Tu es un beau chat.'
# -> Prédiction : True (Scores : {'True': 16, 'False': 12})
# Phrase : 'Les plumes de cet animal chatoient.'
# -> Prédiction : False (Scores : {'True': 45, 'False': 48})
# Phrase : 'La facture a été payée'
# -> Prédiction : True (Scores : {'True': 25, 'False': 23})

# %% [markdown]
# Les modèles inductifs ne sont pas par définition opaques : un accès aux données d'entrainement et à la logique de mise en relation du document avec la catégorie peut rendre transparente la prédiction.

# %%
# Essayer avec d'autres phrases

votre_phrase = input("Entrez votre phrase à classer")

categorie, scores = classifier_nouvelle_phrase(votre_phrase)
print(f"-> Prédiction : {categorie} (Scores : {scores})")
# Out:
# -> Prédiction : False (Scores : {'True': 16, 'False': 18})

# %%
def classifier_nouvelle_phrase_detailed(texte_nouveau):
    mots = texte_nouveau.lower().split()
    scores_prediction = {"True": 0, "False": 0}

    # 2. Stockage des contributions par mot (NOUVEAU)
    contributions_par_mot = {}

    for mot in mots:
        if mot in modele_appris:
            # On met à jour le score global
            for categorie in scores_prediction:
                scores_prediction[categorie] += modele_appris[mot][categorie]

            # On enregistre combien ce mot a contribué à chaque catégorie
            contributions_par_mot[mot] = modele_appris[mot].copy()
        else:
            contributions_par_mot[mot] = {"True": 0, "False": 0}

    # On trouve le gagnant
    categorie_gagnante = max(scores_prediction, key=scores_prediction.get)

    # On retourne TOUT : la catégorie, le score global, et le détail par mot
    return categorie_gagnante, scores_prediction, contributions_par_mot

# --- TEST AVEC DÉTAIL ---
print("\n--- Analyse détaillée des contributions ---")
phrase_test = "Le chien est un animal domestique. Les poires sont des fruits."
cat, scores, details = classifier_nouvelle_phrase_detailed(phrase_test)

print(f"Phrase : '{phrase_test}'")
print(f"Prédiction finale : {cat} (Score total : {scores})")
print("\nContribution de chaque mot (qui a fait pencher la balance) :")
print(details)
# On trie les mots par "impact" (différence entre le score max et min pour ce mot)
# ou simplement on affiche les scores bruts pour voir les "gros" nombres.
for mot, scores_mot in details.items():
    if mot != "": # On ignore les espaces vides si nécessaire
        # On calcule l'impact : la différence entre la catégorie gagnante et les autres
        impact = scores_mot[cat] - max([v for k, v in scores_mot.items() if k != cat])

        # Affichage formaté
        print(f"  - Mot '{mot}' : {scores_mot}")
        if scores_mot[cat] > 0:
            print(f"      -> A apporté {scores_mot[cat]} point(s) à '{cat}'")
        else:
          print(f"        -> N'était pas présent dans les données d'entrainement.")
# Out:
# --- Analyse détaillée des contributions ---
# Phrase : 'Le chien est un animal domestique. Les poires sont des fruits.'
# Prédiction finale : False (Score total : {'True': 41, 'False': 61})
#
# Contribution de chaque mot (qui a fait pencher la balance) :
# {'le': {'True': 11, 'False': 15}, 'chien': {'True': 2, 'False': 0}, 'est': {'True': 1, 'False': 4}, 'un': {'True': 2, 'False': 6}, 'animal': {'True': 0, 'False': 0}, 'domestique.': {'True': 0, 'False': 0}, 'les': {'True': 15, 'False': 21}, 'poires': {'True': 0, 'False': 0}, 'sont': {'True': 1, 'False': 4}, 'des': {'True': 9, 'False': 11}, 'fruits.': {'True': 0, 'False': 0}}
#   - Mot 'le' : {'True': 11, 'False': 15}
#       -> A apporté 15 point(s) à 'False'
#   - Mot 'chien' : {'True': 2, 'False': 0}
#         -> N'était pas présent dans les données d'entrainement.
#   - Mot 'est' : {'True': 1, 'False': 4}
#       -> A apporté 4 point(s) à 'False'
#   - Mot 'un' : {'True': 2, 'False': 6}
#       -> A apporté 6 point(s) à 'False'
#   - Mot 'animal' : {'True': 0, 'False': 0}
#         -> N'était pas présent dans les données d'entrainement.
#   - Mot 'domestique.' : {'True': 0, 'False': 0}
#         -> N'était pas présent dans les données d'entrainement.
#   - Mot 'les' : {'True': 15, 'False': 21}
#       -> A apporté 21 point(s) à 'False'
#   - Mot 'poires' : {'True': 0, 'False': 0}
#         -> N'était pas présent dans les données d'entrainement.
#   - Mot 'sont' : {'True': 1, 'False': 4}
#       -> A apporté 4 point(s) à 'False'
#   - Mot 'des' : {'True': 9, 'False': 11}
#       -> A apporté 11 point(s) à 'False'
#   - Mot 'fruits.' : {'True': 0, 'False': 0}
#         -> N'était pas présent dans les données d'entrainement.
